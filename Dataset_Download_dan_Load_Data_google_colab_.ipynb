# %% [markdown]
# <a href="https://colab.research.google.com/github/SanggarLucky/Tutorial_Google_Colab/blob/master/Dataset_Download_dan_Load_Data_google_colab_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Google Colab
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1Hwt7Y-3ydxdE7noRVWwbqRBUzCi9GozY?usp=sharing)
#
# Jika Anda ingin membuat machine learning, mencoba data analisis python tapi gak punya komputer yang cukup baik maka Google Colab adalah pilihannya. Ditambah lagi tanpa perlu instalasi, bisa langsung menjalankan python notebook secara instan. Hebatnya lagi bisa menggunakan GPU dan TPU dengan gratis.

# %% [markdown]
# ##Instalasi Library yang belum tersedia
# Untuk mengimpor perpustakaan yang tidak ada di Colab, Anda dapat menggunakan `! Pip install` atau`! Apt-get install`.

# %%
# !pip install tweepy

# %% [markdown]
# ## Cara mengupload atau mendownload data set dengan mudah
# Berikut adalah cara-cara yang digunakan
# 1. Melalui Google Drive
# 2. Dari Kaggle
# 3. Download dengan wget
# 4. Dataset bawaan library
# 5. Clone project dari github
# 6. Import data dari Google Sheet
# 7. Upload langsung dari data lokal
#
# Perlu diingat dataset akan hilang setelah kita login lagi. Jadi sebaiknya simpan data di github atau google drive untuk mempermudah bekerja dengan dataset yang sama di lain waktu.

# %% [markdown]
# ### Dengan mount Google Drive
# Contoh di bawah ini menunjukkan cara memasang Google Drive di mesin virtual Anda menggunakan kode otorisasi. Klik link yang disediakan dan copy kode otorisasi ke dalam form. File dapat dilihat pada toolbar samping kiri dalam icon folder

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# ### Download langsung dari Kaggle
# Kaggle.com adalah  web paling populer di kalangan Data Scientist dan . Meskipun Kaggle belum sepopuler GitHub, ini adalah platform pendidikan sosial yang sedang naik daun.
#
# Anda dapat menemukan dataset melalui kaggle dan bisa langsung download data ke Google Colab. Pertama adalah buat akun di kaggle dan buat API di Kaggle seperti pada gambar di bawah ini. Save file API JSON di drive dan bisa di mount seperti langkah sebelumnya

# %%
#@title
from google.colab.patches import cv2_imshow
import cv2
img = cv2.imread('/content/gdrive/My Drive/Image Asset/Kaggle.JPG')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1292x703 at 0x7FE72ADAFB00>

# %%
# Berikut adalah snippet yang berguna buat hemat waktu
# !pip install -q kaggle
# !mkdir -p ~/.kaggle
#copy dari lokasi drive dimana file kaggle.json
# %cd /content/gdrive/My Drive/
# !cp kaggle.json ~/.kaggle/
# !ls ~/.kaggle
# !chmod 600 /root/.kaggle/kaggle.json

! kaggle datasets list
# Out:
# /content/gdrive/My Drive
# kaggle.json
# ...
# ref                                                         title                                                size  lastUpdated          downloadCount
# ----------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------
# allen-institute-for-ai/CORD-19-research-challenge           COVID-19 Open Research Dataset Challenge (CORD-19)    3GB  2020-06-23 00:53:41             92
# roche-data-science-coalition/uncover                        UNCOVER COVID-19 Challenge                          179MB  2020-05-21 18:57:53           3613
# madeleineferguson/farmers-markets-in-the-united-states      Farmers Markets in the United States                816KB  2020-06-10 16:41:46             34
# rohan0301/unsupervised-learning-on-country-data             Unsupervised Learning on Country Data                 5KB  2020-06-17 07:45:45             30
# ...

# %%
#misalnya memilih dataset yang diatas atau bisa cari sendiri lewat websita kaggle dan menggunakan link url setelah kaggle.com
# %cd /content/
# !kaggle datasets download -d promptcloud/jobs-on-naukricom
# Out:
# /content
# ...
#   0% 0.00/2.99M [00:00<?, ?B/s]
# 100% 2.99M/2.99M [00:00<00:00, 96.0MB/s]

# %%
# !unzip  '/content/jobs-on-naukricom.zip'
# Out:
# Archive:  /content/jobs-on-naukricom.zip
# replace home/sdf/marketing_sample_for_naukri_com-jobs__20190701_20190830__30k_data.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: home/sdf/marketing_sample_for_naukri_com-jobs__20190701_20190830__30k_data.csv

# %% [markdown]
# ### Download data dengan wget
#
# Jika Anda sudah memiliki link data untuk di download bisa langsung di copy link adrress dan download. Berikut adalah caranya dengan sangat sederhana. Contohnya data dari [UC Irvine Machine Learning Repository](https://https://archive.ics.uci.edu/ml/index.php)

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data  # URL of your file
# Out:
# --2020-06-24 07:25:49--  https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4551 (4.4K) [application/x-httpd-php]
# Saving to: ‘iris.data’
#
# iris.data           100%[===================>]   4.44K  --.-KB/s    in 0s
#
# 2020-06-24 07:25:50 (104 MB/s) - ‘iris.data’ saved [4551/4551]

# %% [markdown]
# ### Mendapatkan dari library
#
# Salah satu cara paling mudah adalah tinggal memanggil dataset yang sudah ada di dalam library itu sendiri. Berikut adalah contohnya dengan memanggil data set MNIST yang sudah ada di dalam library tensorflow dengan tipe data yang sudah siap ditraining.

# %%
import tensorflow_datasets as tfds
import tensorflow as tf

ds_train = tfds.load('mnist', split='train', shuffle_files=True)
ds_train
# Out:
# <DatasetV1Adapter shapes: {image: (28, 28, 1), label: ()}, types: {image: tf.uint8, label: tf.int64}>

# %% [markdown]
# Atau dataset iris langsung dari SKlearn
# *  load_boston
# *  load_iris
# *  load_diabetes
# *  load_digits
# *  load_linnerud
# *  load_wine
# *  load_breast_cancer

# %%
from sklearn import datasets
iris = datasets.load_iris()

# %% [markdown]
# ### Mendapatkan dataset dari Github
#
# Jika Anda bekerja pada proyek yang memiliki dataset sendiri dan ingin menarik dataset dari GitHub secara langsung.
#
# Buka repo GitHub dan salin URL dari clone

# %%
# !git clone https://github.com/emorisse/FBI-Hate-Crime-Statistics.git
# Out:
# Cloning into 'FBI-Hate-Crime-Statistics'...
# remote: Enumerating objects: 28, done.
# remote: Total 28 (delta 0), reused 0 (delta 0), pack-reused 28
# Unpacking objects: 100% (28/28), done.

# %% [markdown]
# ## Load Dataset dengan Pandas

# %%
import pandas as pd
iris_df = pd.read_csv('/content/iris.data', header= None)
iris_df
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]
